# %% [markdown]
# <a href="https://colab.research.google.com/github/Ray-Mun-Ben/-AI-Coursework-2025/blob/main/Netflix_Titles_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#from google.colab import files
#uploaded = files.upload()
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. How many rows and columns are contained in the dataset?

# %%
import pandas as pd
#df = pd.read_csv('netflix_titles.csv')
df = pd.read_csv('/content/drive/MyDrive/netflix_titles.csv')

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# 2. What datatypes are contained in the dataset?

# %%
df.info()
#or df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# 3. Is the dataset complete? i.e no missing values?
#
# Director, cast, country, date_added, rating and duration have missing values.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# 4. List the number of Movies and TV Shows among the last 20 rows
# of the dataset.

# %%
df.tail(20)
# Out:
#      show_id     type                          title                 director  \
# 8787   s8788    Movie      You Can’t Fight Christmas              Kenny Young
# 8788   s8789    Movie                   You Carry Me               Ivona Juka
# 8789   s8790    Movie            You Changed My Life      Cathy Garcia-Molina
# 8790   s8791    Movie  You Don't Mess with the Zohan             Dennis Dugan
# 8791   s8792    Movie                    Young Adult            Jason Reitman
# 8792   s8793    Movie                    Young Tiger                   Mu Chu
# 8793   s8794    Movie           Yours, Mine and Ours             Raja Gosnell
# 8794   s8795    Movie                         اشتباك             Mohamed Diab
# 8795   s8796  TV Show                Yu-Gi-Oh! Arc-V                      NaN
# 8796   s8797  TV Show                     Yunus Emre                      NaN
# 8797   s8798  TV Show                      Zak Storm                      NaN
# ...

# %% [markdown]
# 1. Give the number of all Movies originating from South Africa

# %%
SouthAfricanMovies = df.query("type == 'Movie' and country == 'South Africa'")
len(SouthAfricanMovies)
# Out:
# 24

# %%
SouthAfricanMovies[['title', 'release_year', 'director']].head()
# Out:
#                              title  release_year        director
# 293                           Slay          2021       Adze Ugah
# 764   Trippin' with the Kandasamys          2021   Jayan Moodley
# 881                 I Am All Girls          2021   Donovan Marsh
# 1172       Loyiso Gola: Unlearning          2021   Kagiso Lediga
# 1905                  Cold Harbour          2013  Carey McKenzie

# %% [markdown]
# 2. What is the description of the movie in the 12th row?

# %%
df.iloc[11]['description']
# Out:
# 'Struggling to earn a living in Bangkok, a man joins an emergency rescue service and realizes he must unravel a citywide conspiracy.'

# %% [markdown]
# 3. From these South African movies, list only those released in 2021

# %%
SA_Movies_2021 = df.query("type == 'Movie' and country == 'South Africa' and release_year == 2021")
SA_Movies_2021[['title', 'release_year', 'description']]
# Out:
#                              title  release_year  \
# 293                           Slay          2021
# 764   Trippin' with the Kandasamys          2021
# 881                 I Am All Girls          2021
# 1172       Loyiso Gola: Unlearning          2021
#
#                                             description
# 293   In pursuit of both success and validation, a g...
# 764   To rekindle their marriages, best friends-turn...
# 881   A relentless detective finds common ground wit...
# 1172  South African comedian Loyiso Gola serves up f...

# %% [markdown]
# 4. List the entire cast of all movies released in 2021.

# %%
Movies2021 = df.query("type == 'Movie' and release_year == 2021")
Movies2021['cast']
# Out:
# 6       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9       Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13      Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 18      Freida Pinto, Logan Marshall-Green, Robert Joh...
#                               ...
# 1425                                                  NaN
# 1431    Engin Günaydın, Haluk Bilginer, Binnur Kaya, Ö...
# 1436    Juan Sebastián Gutiérrez, Pablo Cano, Pablo Me...
# 1466                                                  NaN
# 1468             Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
# Name: cast, Length: 277, dtype: object
